# %% [markdown]
# <a href="https://colab.research.google.com/github/davidebtt/chemical_pycode/blob/chemical-calculator/proportion_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Description:
#
# This code allows you to solve a proportion of the form A:B = C:x, where
#
# A, B, and  C are known values, and you need to find the value of x.
#
# How to Use:
#
# Run the script.
#
# When prompted, enter the value for A.
#
# Enter the value for B.
#
# Enter the value for C.
#
# The script will calculate and display the value of x (D), rounded to two decimal places.
#
# This is useful for solving basic ratios and proportions in various mathematical problems.

# %%
print("A:B = C:x")
A = float(input("Enter number A: "))
B = float(input("Enter number B: "))
C = float(input("Enter number C: "))
x = round((B * C) / A, 2)

print(f"x is {x}")
# Out:
# A:B = C:x
# Enter number A: 23.9
# Enter number B: 19.69
# Enter number C: 23.02
# x is 18.97

# %% [markdown]
# Find alo the multiplication factor and adapt the procedure to scale it up!

# %%
print("A:B = C:x")

A = float(input("Enter number A: "))
B = float(input("Enter number B: "))
C = float(input("Enter number C: "))

# Calculate multiplication factor and x
factor = round((B / A),2)
x = round(C * factor, 2)


print(f"x is {x}")
print(f"Multiplication factor is {factor}")
# Out:
# A:B = C:x
# Enter number A: 0.254
# Enter number B: 5
# Enter number C: 0.218
# Multiplication factor is 19.69
# x is 4.29
