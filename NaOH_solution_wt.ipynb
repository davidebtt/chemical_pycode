# %% [markdown]
# <a href="https://colab.research.google.com/github/davidebtt/chemical_pycode/blob/liquid-phase/NaOH_solution_wt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
{
    concentration: {
        temperature: density,
        ...
    },
    ...
}

# %%
naoh_density_data = {
    1:  {0: 1.0124, 15: 1.0165, 20: 1.0095, 40: 1.0033, 60: 0.9941, 80: 0.9824, 100: 0.9693},
    2:  {0: 1.0244, 15: 1.02198, 20: 1.0207, 40: 1.0139, 60: 1.0045, 80: 0.9929, 100: 0.9797},
    4:  {0: 1.0482, 15: 1.0441, 20: 1.0428, 40: 1.0352, 60: 1.0254, 80: 1.0139, 100: 1.0009},
    8:  {0: 1.0943, 15: 1.0887, 20: 1.0869, 40: 1.0780, 60: 1.0660, 80: 1.0432, 100: 1.0247},
    12: {0: 1.1399, 15: 1.13327, 20: 1.1309, 40: 1.1210, 60: 1.1101, 80: 1.0983, 100: 1.0855},
    16: {0: 1.1849, 15: 1.17761, 20: 1.1751, 40: 1.1645, 60: 1.1531, 80: 1.1383, 100: 1.1277},
    20: {0: 1.2296, 15: 1.22183, 20: 1.2191, 40: 1.2079, 60: 1.1960, 80: 1.1833, 100: 1.1720},
    24: {0: 1.2741, 15: 1.2658, 20: 1.2635, 40: 1.2508, 60: 1.2388, 80: 1.2239, 100: 1.2104},
    28: {0: 1.3182, 15: 1.3094, 20: 1.3064, 40: 1.2942, 60: 1.2814, 80: 1.2682, 100: 1.2546},
    32: {0: 1.3620, 15: 1.3520, 20: 1.3499, 40: 1.3378, 60: 1.3247, 80: 1.3101, 100: 1.2950},
    36: {0: 1.4030, 15: 1.3933, 20: 1.3900, 40: 1.3768, 60: 1.3634, 80: 1.3498, 100: 1.3360},
    40: {0: 1.4435, 15: 1.4339, 20: 1.4300, 40: 1.4161, 60: 1.4027, 80: 1.3889, 100: 1.3750},
    44: {0: 1.4825, 15: 1.4720, 20: 1.4685, 40: 1.4541, 60: 1.4405, 80: 1.4266, 100: 1.4127},
    48: {0: 1.5210, 15: 1.5120, 20: 1.5065, 40: 1.4922, 60: 1.4781, 80: 1.4641, 100: 1.4503},
    50: {0: 1.5400, 15: 1.5290, 20: 1.5253, 40: 1.5109, 60: 1.4967, 80: 1.4827, 100: 1.4690}
}

# %%
# User inputs
NaOH_d = float(input("Insert NaOH density in g/ml: "))
NaOH_percent = float(input("Insert the percent % wt of your solution: "))
volume_ml = float(input("Insert the volume of the solution in ml: "))

# Calculations
NaOH_g = round((NaOH_d * volume_ml) * (NaOH_percent / 100), 2)
solution_weight = round(volume_ml * NaOH_d, 2)

# Output
print(f"Weight {NaOH_g} g of NaOH and add pure H2O until you reach {solution_weight} g total. Then stir until you get a clear solution and measure the density.")
# Out:
# Insert NaOH density in g/ml: 1.1309
# Insert the percent % wt of your solution: 12
# Insert the volume of the solution in ml: 350
# Weight 47.5 g of NaOH and add pure H2O until you reach 395.81 g total. Then stir until you get a clear solution and measure the density.
