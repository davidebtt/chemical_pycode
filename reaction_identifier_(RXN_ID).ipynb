# %% [markdown]
# <a href="https://colab.research.google.com/github/davidebtt/chemical_pycode/blob/chemical-calculator/reaction_identifier_(RXN_ID).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reaction identifier (RXN-ID)** With this code, you can enter your reaction data quickly and get all the information you need for your lab journal in an instant. It helps keep your work organized and efficient, making it easy to use in your daily lab activities.
#
# The goal is to remove boring, repetitive tasks from your to-do list, freeing your mind for creative work. Use your brain to invent amazing new reactions, not to store data—this job can be done in seconds, leaving you free to focus on what you enjoy most!

# %%
from datetime import datetime

def get_date_input(prompt):
    """ Get a valid date input from the user in the format YYYY-MM-DD. """
    while True:
        date_str = input(prompt)
        try:
            return datetime.strptime(date_str, "%Y-%m-%d").date()
        except ValueError:
            print("Invalid date format. Please enter the date in YYYY-MM-DD format.")

def generate_experiment_id(name, project_type):
    """ Generate a unique RXN-ID using the experiment name, project type, and timestamp. """
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
    return f"{name}_{project_type}_{timestamp}"

def main():
    print("### Reaction Identifier (RXN-ID) ###")

    project_type = input("Insert the project type (internal/custom): ").strip().lower()
    name = input("Insert the name of the experiment: ").strip()

    starting_date = get_date_input("Insert the start date (YYYY-MM-DD): ")
    end_date = get_date_input("Insert the end date (YYYY-MM-DD): ")

    experiment_purpose = input("Insert the purpose of your experiment: ").strip()
    results = input("Insert the results of your experiment: ").strip()

    experiment_id = generate_experiment_id(name, project_type)

    print("\n--- Experiment Details ---")
    print(f"Experiment ID: {experiment_id}")
    print(f"Project Type: {project_type.capitalize()}")
    print(f"Name: {name}")
    print(f"Start Date: {starting_date}")
    print(f"End Date: {end_date}")
    print(f"Purpose: {experiment_purpose}")
    print(f"Results: {results}")

if __name__ == "__main__":
    main()
# Out:
# ### Reaction Identifier (RXN-ID) ###
# Insert the project type (internal/custom): internal
# Insert the name of the experiment: DB_XXX
# Insert the start date (YYYY-MM-DD): 2025-03-17
# Insert the end date (YYYY-MM-DD): 2025-03-18
# Insert the purpose of your experiment: Attempt to synthesize the molecule XXX.
# Insert the results of your experiment: reaction successful!
#
# --- Experiment Details ---
# Experiment ID: DB_XXX_internal_20250317084635
# Project Type: Internal
# Name: DB_XXX
# Start Date: 2025-03-17
# End Date: 2025-03-18
# Purpose: Attempt to synthesize the molecule XXX.
# Results: reaction successful!
