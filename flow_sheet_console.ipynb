# %% [markdown]
# <a href="https://colab.research.google.com/github/davidebtt/chemical_pycode/blob/Process-chemistry-R%26D/flow_sheet_console.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# flow_console.py
# Build a simple vertical flow sheet from user inputs using f-strings

print("Enter each step of your process (blank line to finish):")

steps = []
while True:
    s = input("> ").strip()
    if not s:
        break
    steps.append(s)

if not steps:
    print("No steps entered.")
    raise SystemExit

# width for neat alignment
inner = max(len(s) for s in steps) + 4

def box(text: str) -> str:
    top = f"┌{'─' * inner}┐"
    mid = f"│{text.center(inner)}│"
    bot = f"└{'─' * inner}┘"
    return f"{top}\n{mid}\n{bot}"

# print the flow sheet
for i, step in enumerate(steps):
    if i > 0:
        print("      │")
        print("      ▼")
    print(box(step))
# Out:
# Enter each step of your process (blank line to finish):
# > charge starting material X
# > charge solvent
# > stirr
# > heat at 50 °C
# > stirr for  x hours
# >
# ┌──────────────────────────────┐
# │  charge starting material X  │
# └──────────────────────────────┘
#       │
#       ▼
# ┌──────────────────────────────┐
# │        charge solvent        │
# └──────────────────────────────┘
#       │
#       ▼
# ┌──────────────────────────────┐
# │            stirr             │
# └──────────────────────────────┘
#       │
#       ▼
# ┌──────────────────────────────┐
# │        heat at 50 °C         │
# └──────────────────────────────┘
#       │
#       ▼
# ┌──────────────────────────────┐
# │      stirr for  x hours      │
# └──────────────────────────────┘
