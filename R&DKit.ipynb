# %% [markdown]
# <a href="https://colab.research.google.com/github/davidebtt/chemical_pycode/blob/cheminformatics/R%26DKit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Draw the molecule using
# https://molview.org/

# %%
# Install RDKit in Colab
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# Install RDKit from conda-forge
# !mamba install -c rdkit rdkit -y
# Out:
# Looking for: ['rdkit']
#
# [+] 0.0s
# rdkit/linux-64 (ch..  ⣾  [+] 0.1s
# rdkit/linux-64 (ch..  ⣾  rdkit/linux-64 (check zst)
# [+] 0.0s
# rdkit/noarch (check zst)                           Checked  0.1s
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# rdkit/linux-64        ⣾
# rdkit/noarch          ⣾  rdkit/linux-64
# rdkit/noarch
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   5%
# conda-forge/noarch     2%[+] 0.3s
# conda-forge/linux-64  12%
# conda-forge/noarch    15%[+] 0.4s
# conda-forge/linux-64  17%
# conda-forge/noarch    33%[+] 0.5s
# conda-forge/linux-64  23%
# conda-forge/noarch    45%[+] 0.6s
# conda-forge/linux-64  28%
# conda-forge/noarch    56%[+] 0.7s
# conda-forge/linux-64  33%
# conda-forge/noarch    61%[+] 0.8s
# conda-forge/linux-64  39%
# conda-forge/noarch    73%[+] 0.9s
# conda-forge/linux-64  46%
# conda-forge/noarch    88%conda-forge/noarch
# [+] 1.0s
# conda-forge/linux-64  53%[+] 1.1s
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors

# Create molecule from SMILES
mol = Chem.MolFromSmiles('CCO')  # ethanol

# Draw and display molecule
img = Draw.MolToImage(mol)
img.show()

# Calculate properties
print("Molecular weight:", Descriptors.MolWt(mol))
print("LogP:", Descriptors.MolLogP(mol))
# Out:
# Molecular weight: 46.069
# LogP: -0.0014000000000000123

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from IPython.display import display

# Molecola: Caffeina
smiles = 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C'
mol = Chem.MolFromSmiles(smiles)

# Disegna e mostra l'immagine
img = Draw.MolToImage(mol)
display(img)

# Calculate and display properties
print("Molecular weight:", Descriptors.MolWt(mol))
print("LogP:", Descriptors.MolLogP(mol))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# Molecular weight: 194.194
# LogP: -1.0293

# %%
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from IPython.display import display

# Molecule: Toluene
smiles = 'Cc1ccccc1'
mol = Chem.MolFromSmiles(smiles)

# Draw and display the molecule image
img = Draw.MolToImage(mol)
display(img)

# Calculate and display properties
print("Molecular weight:", Descriptors.MolWt(mol))
print("LogP:", Descriptors.MolLogP(mol))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# Molecular weight: 92.14099999999999
# LogP: 1.99502
